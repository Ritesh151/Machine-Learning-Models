# %% [markdown]
# # Part-1: Data Exploration and Pre-processing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report

# %% [markdown]
# #### 1) load the given Dataset
#
# #### 2) check the null values
#
# #### 3) print the column names

# %%
Data = pd.read_csv("./Data.csv")
display(Data)

Null = Data.isnull().mean() * 100
print(Null)

Cols = Data.columns
print(Cols)

# %% [markdown]
# #### 4) create list for all the columns which have null values
#
# #### 5) fill all the null values with mean using for loops

# %%
Null_Cols = [col for col in Data.columns if Data[col].isnull().sum() > 0]
Null_Cols

for col in Null_Cols:
    Data[col].fillna(Data[col].mean(), inplace=True)

display(Data)

# %% [markdown]
# #### 6) get data information
#
#
# #### 7) describe dataset

# %%
Info = Data.info()
print(Info)

print("\n\nDescribe")
Stats = Data.describe()
display(Stats)

# %% [markdown]
# #### 8) display box plot for LIMIT_BAL
#
#
# #### 9) display box plot for AGE

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=Data["LIMIT_BAL"])
plt.show()

plt.figure(figsize=(6,4))
sns.boxplot(x=Data["AGE"])
plt.show()

# %% [markdown]
# #### 10) drop all the null values
#
#
# #### 11) perform encoding on default status

# %%
Data.dropna(inplace=True)

Encoder = LabelEncoder()
Data["Default Status"] = Encoder.fit_transform(Data["Default Status"])

display(Data)

# %% [markdown]
# ##

# %% [markdown]
# # Part-2: Working with Models

# %% [markdown]
# #### 1) Create a features and target dataset
#
# #### 2) Split data into training and testing
#
# #### 3) Fit the Gaussian naive bayes classifier

# %%
X = Data.drop(columns=["Default Status"])
Y = Data["Default Status"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

Model = GaussianNB()
Model.fit(X_train, Y_train)

Y_Pred = Model.predict(X_test)

# %% [markdown]
# #### 4) Print the training and
#
#
# #### 5) Print the testing score
#
#
# #### 6) Find the accuracy score
#
#
# #### 7) Find the precision score
#
#
# #### 8) Find the recall score
#
#
# #### 9) Find the confusion matrix
#
#
# #### 10) Find the Classification report

# %%
print("Training Score:", Model.score(X_train, Y_train) * 100)
print("Testing Score:", Model.score(X_test, Y_test) * 100)


Accuracy = accuracy_score(Y_test, Y_Pred) * 100
print("\nAccuracy = ", Accuracy)

Precision = precision_score(Y_test, Y_Pred) * 100
print("\nPrecision =", Precision)

ReCall = recall_score(Y_test, Y_Pred) * 100
print("\nRecall Score = ", ReCall)


plt.figure(figsize=(12,6))
sns.heatmap(confusion_matrix(Y_test, Y_Pred), annot=True, cmap='coolwarm', fmt='g')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Classes")
plt.ylabel("Actual Classes")
plt.show()

print("\nClassification Report:")
print(classification_report(Y_test, Y_Pred))


print("\nClassification Report")
Report = classification_report(Y_test, Y_Pred)
print(Report)
# Out:
# Training Score: 84.47179654385393
# Testing Score: 83.37679269882659
#
# Accuracy =  83.37679269882659
#
# Precision = 85.33064786841223
#
# Recall Score =  97.20841300191204
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.18      0.04      0.06       453
#            1       0.85      0.97      0.91      2615
#
#     accuracy                           0.83      3068
#    macro avg       0.52      0.50      0.48      3068
# weighted avg       0.75      0.83      0.78      3068
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.18      0.04      0.06       453
#            1       0.85      0.97      0.91      2615
#
#     accuracy                           0.83      3068
#    macro avg       0.52      0.50      0.48      3068
# weighted avg       0.75      0.83      0.78      3068
